# %% [markdown]
# # COVID 19 DATA SET

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\buffarang\\Projectrs\\covid19data.csv")

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
df.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
# Number of confirmed deaths and recovered cases in each region

# %%
df.head(3)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702

# %%
# Grouping by different regions

# %%
df.groupby("Region").sum().head(10)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779

# %%
# Showing number of Confirmed death in Countries

# %%
df.groupby("Region")['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
# Sorting Confirmed death in Countries.

# %%
df.groupby("Region")['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
# Showing Confirmed and Recovered in Countries.

# %%
df.groupby("Region")['Confirmed', 'Recovered'].sum()
# Out:
# <ipython-input-52-8c1a9bc096a4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Region")['Confirmed', 'Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %%
# Removing records where Confirmed cases less than 10

# %%
df[df.Confirmed < 10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
# Syntax for removing reconds less than 10

# %%
df[~(df.Confirmed < 10)].head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %%
# removing the conditional data

# %%
#df = df[~(df.Confirmed < 10)].head(20)

# %%
# Which region had the maximum Cases

# %%
df.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
# Which region had the maximum Deaths

# %%
df.groupby("Region").Deaths.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                60967
# Italy             27682
# UK                26166
# Spain             24275
# France            24121
# Belgium            7501
# Germany            6467
# Iran               5957
# Brazil             5513
# Netherlands        4727
# Mainland China     4633
# Canada             3155
# Turkey             3081
# Sweden             2462
# Mexico             1732
# Switzerland        1716
# Ireland            1190
# India              1079
# Portugal            973
# Russia              972
# Name: Deaths, dtype: int64

# %%
# How many Confirmed, Death & Recovered cases reported in Belgium till 29 April 2020

# %%
df.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
df[df.Region == 'Belgium']
# Out:
#          Date State   Region  Confirmed  Deaths  Recovered
# 15  4/29/2020   NaN  Belgium      47859    7501      11283

# %%
# show the no of Cases in ascending order.

# %%
df.sort_values( by = ['Confirmed'], ascending = True).head(10)
# Out:
#           Date                             State          Region  Confirmed  \
# 285  4/29/2020                         Recovered              US          0
# 284  4/29/2020                         Recovered          Canada          0
# 203  4/29/2020      Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                             Tibet  Mainland China          1
# 289  4/29/2020         Saint Pierre and Miquelon          France          1
# 184  4/29/2020                          Anguilla              UK          3
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba     Netherlands          5
# 272  4/29/2020             Northwest Territories          Canada          5
# 288  4/29/2020                  Saint Barthelemy          France          6
# 178  4/29/2020                               NaN           Yemen          6
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# 305       0          1
# ...

# %%
# Sort the no of Recovered cases in descending order

# %%
df.sort_values( by = ['Recovered'], ascending = False).head(10)
# Out:
#           Date      State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020        NaN           Spain     236899   24275     132929
# 285  4/29/2020  Recovered              US          0       0     120720
# 61   4/29/2020        NaN         Germany     161539    6467     120400
# 76   4/29/2020        NaN            Iran      93657    5957      73791
# 80   4/29/2020        NaN           Italy     203591   27682      71252
# 229  4/29/2020      Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020        NaN          France     165093   24087      48228
# 167  4/29/2020        NaN          Turkey     117589    3081      44040
# 22   4/29/2020        NaN          Brazil      79685    5513      34132
# 158  4/29/2020        NaN     Switzerland      29407    1716      22600
